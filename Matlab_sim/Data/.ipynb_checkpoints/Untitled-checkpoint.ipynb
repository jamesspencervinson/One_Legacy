# %%
import pandas as pd
from scipy.io import loadmat

# %%
df = loadmat('est_data_1h_v2.mat')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/scipy/io/matlab/mio.py:218: MatReadWarning: Duplicate variable name "None" in stream - replacing previous with new
# Consider mio5.varmats_from_mat to split file into single variable files
#   matfile_dict = MR.get_variables(variable_names)

# %%
df
# Out:
# {'__header__': b'MATLAB 5.0 MAT-file, Platform: MACI64, Created on: Mon May  4 10:03:55 2020',
#  '__version__': '1.0',
#  '__globals__': [],
#  'HR_allocated': array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'HR_available': array([[1],
#         [1],
#         [1],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'LI_allocated': array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'LI_available': array([[1],
#         [1],
#         [1],
#         ...,
#         [1],
#         [1],
#         [1]], dtype=uint8),
#  'LU_allocated': array([[0],
#         [0],
#         [0],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'LU_available': array([[2],
#         [2],
#         [2],
#         ...,
#         [0],
#         [0],
#         [0]], dtype=uint8),
#  'abo_o': array([[1],
#         [1],
# ...
